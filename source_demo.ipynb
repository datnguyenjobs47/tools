# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from playwright_handler import *
import logging

# %%
#103.207.36.217:8128:iR276g8Ostyle:CDTwwWWP

# %%
logging.basicConfig(level=logging.INFO)

proxy = {
    "server":   "http://103.125.189.149:8994",
    "username": "UE5CyRotstyle",
    "password": "WOJcMhA9",
}
# 103.125.189.149:8994:UE5CyRotstyle:WOJcMhA9

# %%
handler = PlaywrightHandler(
    browser_type="chrome",
    headless=False,
    # device=None,
    proxy=proxy,
    browser_id=9,
    is_mobile=True,
    # monitor_network=True,
    keep_profile=False
)
browser = await handler.__aenter__()
# Out:
# INFO:ProxyMiddleware:Auth enabled for upstream proxy: 103.125.189.149:8994
# INFO:playwright_handler:Proxy middleware started on port 8809
# INFO:playwright_handler:Browser 9 started (platform=win32, mobile=True, keep_profile=False)

# %%
page = await browser.get_page()
# await page.evaluate("""window.location.href = "https://m.auction.co.kr/";""")
# Out:
# INFO:playwright_handler:Fingerprint emulation applied: Mobile (412x915 @3x)

# %%
await page.goto("https://m.auction.co.kr/")
# Out:
# <Response url='https://m.auction.co.kr/' request=<Request url='https://m.auction.co.kr/' method='GET'>>
